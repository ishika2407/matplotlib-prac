# %%
#SCATTER
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,7,8,9]
y=[3,4,5,6,7,8,1,2,11]
x1=[1,3,4,5,7,9,12,9,5]
y1=[9,8,7,6,5,4,3,2,1]
#plt.figure(figsize=(16,19))
plt.title("isbsj")
plt.scatter(x,y, color="orange", marker="*", alpha=0.9, s=100, label="abc")
plt.scatter(x1,y1, color="green", marker="o", alpha=0.9, s=30, label="def")
#plt.xlabel("TEMP")
#plt.ylabel("DAYS")
#plt.legend()
plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#PIE-CHART
import matplotlib.pyplot as plt
student_performance=["Excellent","Good","Average","Poor"]
values=[15,25,12,8]
plt.pie(values,labels=student_performance,colors=["orange","yellow","pink","green"], radius=0.9, labeldistance=1.2, autopct="%2.1f%%",
       explode=[0.2,0,0,0],shadow=True,textprops={"fontsize":11})
#rotatelabels=True
plt.legend(title="PERFORMANCE", loc=(1,1))
plt.show()

# %%
#BOXPLOT
import matplotlib.pyplot as plt
data=[10,20,30,40,50]
plt.boxplot(data)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#HEXAGONAL BIN PLOT
import matplotlib.pyplot as plt
import numpy as np
x=np.random.normal(size=(1,10000))
y=np.random.normal(size=(1,10000))
plt.hexbin(x,y,gridsize=35,cmap="plasma") #inferno
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
A=[12,10,15,13,16,23,25,28,29,26,35,45,16,48,47,65,64,68,82]
B=[10,23,20,25,26,54,50,23,30,54]
plt.hist(A, bins=[15,20,25,30,35,40,45], rwidth=0.8,histtype="bar",orientation="vertical", color="r", label="abc")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import seaborn as sns
t = sns.load_dataset('iris')
t.head()
#sns.pairplot(t)
#sns.countplot(x='sepal_length', data=t)
#sns.barplot(x='sepal_length', y='sepal_width', data=t)
#sns.boxplot(x='sepal_length', y='sepal_width', data=t)
sns.violinplot(x='sepal_length', y='sepal_width', data=t)
sns.stripplot(x='sepal_length', y='sepal_width', data=t)
#sns.catplot(x='sepal_length', y='sepal_width', data=t)
#sns.kdeplot(x='sepal_length', data=t)
#sns.displot(x='sepal_length',kde=True, bins=5, data=t)
#sns.scatterplot(x='sepal_length', y='sepal_width', data=t)
#sns.jointplot(x='sepal_length', y='sepal_width', data=t, kind='reg')
#corr=t.corr()
#sns.heatmap(corr)
sns.lineplot(x='sepal_length',y='sepal_width',data=t)
#sns.replot(x,y)
sns.lmplot(x='sepal_length', y='sepal_width', data=t)
#sns.swasmplot(x='sepal_length', y='sepal_width', data=t)
t.plot(x='sepal_length', y='sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length'>

# %%
sns.lmplot(x='sepal_length', y='sepal_width', data=t)

# %%
sns.displot(x='sepal_length',kde=True, bins=5, data=t)

# %%
sns.swasmplot(x='sepal_length', y='sepal_width', data=t)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-82f8e1cdf766> in <module>
# ----> 1 sns.swasmplot(x='sepal_length', y='sepal_width', data=t)
#
# AttributeError: module 'seaborn' has no attribute 'swasmplot'

# %%
#stemming
from nltk.stem import PorterStemmer
ps = PorterStemmer()
en = ['python', 'pythoned', 'pythoning', 'pythonly']
for w in en:
    print(ps.stem(w))
# Out:
# python
# python
# python
# pythonli

# %%
#partofspeech
import nltk
nltk.download('averaged_perceptron_tagger')
from nltk import pos_tag
text = ['Ishika']
print(nltk.pos_tag(text))
# Out:
# [('Ishika', 'FW')]
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
import nltk
sentence= "This is nltk"
grammar = 'NP' : {<DT>?<JJ>*<NN>}
    parser = nltk.RegexpParser(grammar)
    op=parser.parser(sentence)
    op.draw()
# Out:
#   File "<ipython-input-30-f3f7d03aa6ec>", line 3
#     grammar = 'NP' : {<DT>?<JJ>*<NN>}
#                    ^
# SyntaxError: invalid syntax

# %% [markdown]
# from nltk import word_tokenize ,pos_tag
# tokens = word_tokenize(tent)
# tag = pos_tag(tokens)
# print(tag)
# ne_tree =nltk.ne_chunk(tag)
# print(ne_tree)

# %%
import matplotlib.pyplot as plt
import numpy as np

# create two sample plots
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

# create a figure and two subplots side by side
fig, axs = plt.subplots(1, 2, figsize=(10, 5))

# plot the first subplot
axs[0].plot(x, y1, color='blue')
axs[0].set_title('Sin(x)')

# plot the second subplot
axs[1].plot(x, y2, color='red')
axs[1].set_title('Cos(x)')

# set overall title for the figure
fig.suptitle('Two Plots Side by Side')

# show the figure
plt.show()
